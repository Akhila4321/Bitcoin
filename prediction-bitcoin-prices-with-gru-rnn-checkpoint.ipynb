# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU
from keras import optimizers 
from sklearn.preprocessing import MinMaxScaler
seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import Data

# %%
bitcoin = pd.read_csv('BTC-USD.csv',index_col='Date', parse_dates=['Date'])
bitcoin
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-09-17   465.864014   468.174011   452.421997   457.334015   457.334015
# 2014-09-18   456.859985   456.859985   413.104004   424.440002   424.440002
# 2014-09-19   424.102997   427.834991   384.532013   394.795990   394.795990
# 2014-09-20   394.673004   423.295990   389.882996   408.903992   408.903992
# 2014-09-21   408.084991   412.425995   393.181000   398.821014   398.821014
# ...                 ...          ...          ...          ...          ...
# 2020-07-05  9126.090820  9162.183594  8977.015625  9073.942383  9073.942383
# 2020-07-06  9072.849609  9375.474609  9058.664063  9375.474609  9375.474609
# 2020-07-07  9349.161133  9360.617188  9201.815430  9252.277344  9252.277344
# 2020-07-08  9253.020508  9450.335938  9249.500000  9428.333008  9428.333008
# 2020-07-09  9431.378906  9431.378906  9355.678711  9357.105469  9357.105469
#
#                  Volume
# Date
# 2014-09-17     21056800
# 2014-09-18     34483200
# 2014-09-19     37919700
# 2014-09-20     36863600
# 2014-09-21     26580100
# ...                 ...
# 2020-07-05  12903406143
# 2020-07-06  17889263252
# 2020-07-07  13839652595
# 2020-07-08  19702359883
# 2020-07-09  18319519744
#
# [2123 rows x 6 columns]

# %%
bitcoin.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
bitcoin.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-07-05  9126.090820  9162.183594  8977.015625  9073.942383  9073.942383
# 2020-07-06  9072.849609  9375.474609  9058.664063  9375.474609  9375.474609
# 2020-07-07  9349.161133  9360.617188  9201.815430  9252.277344  9252.277344
# 2020-07-08  9253.020508  9450.335938  9249.500000  9428.333008  9428.333008
# 2020-07-09  9431.378906  9431.378906  9355.678711  9357.105469  9357.105469
#
#                  Volume
# Date
# 2020-07-05  12903406143
# 2020-07-06  17889263252
# 2020-07-07  13839652595
# 2020-07-08  19702359883
# 2020-07-09  18319519744

# %%
bitcoin.shape
# Out:
# (2123, 6)

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2123 entries, 2014-09-17 to 2020-07-09
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2123 non-null   float64
#  1   High       2123 non-null   float64
#  2   Low        2123 non-null   float64
#  3   Close      2123 non-null   float64
#  4   Adj Close  2123 non-null   float64
#  5   Volume     2123 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 116.1 KB

# %%
bitcoin.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
bitcoin.duplicated().sum()
# Out:
# 0

# %%
bitcoin.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
bitcoin.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2123.000000   2123.000000   2123.000000   2123.000000   2123.000000
# mean    4185.932266   4294.749473   4069.363555   4190.018268   4190.018268
# std     4029.791354   4152.358417   3886.728318   4030.549405   4030.549405
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      425.334488    432.388504    420.620514    424.749497    424.749497
# 50%     3341.840088   3453.449951   3247.669922   3378.939941   3378.939941
# 75%     7509.315185   7696.606445   7374.902588   7531.821777   7531.821777
# max    19475.800781  20089.000000  18974.099609  19497.400391  19497.400391
#
#              Volume
# count  2.123000e+03
# mean   7.431161e+09
# std    1.144642e+10
# min    5.914570e+06
# 25%    5.841410e+07
# 50%    1.537460e+09
# 75%    1.004265e+10
# max    7.415677e+10

# %%
df = pd.DataFrame(bitcoin['Close'])
print(' Count row of data: ',len(df))
# Out:
#  Count row of data:  2123

# %%
df.describe()
# Out:
#               Close
# count   2123.000000
# mean    4190.018268
# std     4030.549405
# min      178.102997
# 25%      424.749497
# 50%     3378.939941
# 75%     7531.821777
# max    19497.400391

# %%
dataset_norm = df.copy()
df[['Close']]
scaler = MinMaxScaler()
dataset_norm['Close'] = scaler.fit_transform(df[['Close']])
dataset_norm
# Out:
#                Close
# Date
# 2014-09-17  0.014453
# 2014-09-18  0.012751
# 2014-09-19  0.011216
# 2014-09-20  0.011947
# 2014-09-21  0.011425
# ...              ...
# 2020-07-05  0.460464
# 2020-07-06  0.476072
# 2020-07-07  0.469695
# 2020-07-08  0.478808
# 2020-07-09  0.475121
#
# [2123 rows x 1 columns]

# %%
fig = plt.figure(figsize=(10, 4))
plt.plot(dataset_norm)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Normalized')
plt.show()

# %%
from datetime import datetime

date_string = '2014-09-17'
parsed_date = datetime.strptime(date_string, '%Y-%m-%d')
timestamp = parsed_date.timestamp()
year = parsed_date.year
month = parsed_date.month
day = parsed_date.day

# %%
# Partition data into data train, val & test
totaldata = df.values
totaldatatrain = int(len(totaldata)*0.7)
totaldataval = int(len(totaldata)*0.1)
totaldatatest = int(len(totaldata)*0.2)

# Store data into each partition
training_set = dataset_norm[0:totaldatatrain]
val_set=dataset_norm[totaldatatrain:totaldatatrain+totaldataval]
test_set = dataset_norm[totaldatatrain+totaldataval:]

# %%
# graph data training
fig = plt.figure(figsize=(10, 4))
plt.plot(training_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Training')
plt.show()

# %%
fig = plt.figure(figsize=(10, 4))
plt.plot(val_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Validation')
plt.show()

# %%
fig = plt.figure(figsize=(10, 4))
plt.plot(test_set)
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Data Test')
plt.show()

# %%
lag = 2
def create_sliding_windows(data,len_data,lag):
    x=[]
    y=[]
    for i in range(lag,len_data):
        x.append(data[i-lag:i,0])
        y.append(data[i,0]) 
    return np.array(x),np.array(y)

# Formating data into array for create sliding windows
array_training_set = np.array(training_set)
array_val_set = np.array(val_set)
array_test_set = np.array(test_set)

# Create sliding windows into training data
x_train, y_train = create_sliding_windows(array_training_set,len(array_training_set), lag)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
# Create sliding windows into validation data
x_val,y_val = create_sliding_windows(array_val_set,len(array_val_set),lag)
x_val = np.reshape(x_val, (x_val.shape[0],x_val.shape[1],1))
# Create sliding windows into test data
x_test,y_test = create_sliding_windows(array_test_set,len(array_test_set),lag)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
x_val
# Out:
# array([[[0.31556412],
#         [0.31615473]],
#
#        [[0.31615473],
#         [0.31641043]],
#
#        [[0.31641043],
#         [0.33222932]],
#
#        [[0.33222932],
#         [0.33220705]],
#
#        [[0.33220705],
#         [0.32953202]],
#
#        [[0.32953202],
#         [0.32602671]],
#
#        [[0.32602671],
#         [0.32544181]],
#
#        [[0.32544181],
#         [0.32667269]],
#
#        [[0.32667269],
#         [0.32631865]],
#
#        [[0.32631865],
#         [0.32656763]],
#
#        [[0.32656763],
#         [0.32597652]],
#
#        [[0.32597652],
#         [0.32701691]],
#
#        [[0.32701691],
#         [0.32600497]],
#
#        [[0.32600497],
#         [0.32592526]],
#
#        [[0.32592526],
#         [0.32621667]],
#
#        [[0.32621667],
#         [0.32652777]],
#
#        [[0.32652777],
#         [0.31856888]],
#
#        [[0.31856888],
#         [0.31865377]],
#
#        [[0.31865377],
#         [0.31779142]],
#
#        [[0.31779142],
#         [0.32090591]],
#
#        [[0.32090591],
#         [0.3214577 ]],
#
#        [[0.3214577 ],
#         [0.32005081]],
#
#        [[0.32005081],
#         [0.32082051]],
#
#        [[0.32082051],
#         [0.32307371]],
#
#        [[0.32307371],
#         [0.32521404]],
#
#        [[0.32521404],
#         [0.32879235]],
#
#        [[0.32879235],
#         [0.32483672]],
#
#        [[0.32483672],
#         [0.32131174]],
#
#        [[0.32131174],
#         [0.32253332]],
#
#        [[0.32253332],
#         [0.32263943]],
#
#        [[0.32263943],
#         [0.32056896]],
#
#        [[0.32056896],
#         [0.31995922]],
#
#        [[0.31995922],
#         [0.28780794]],
#
#        [[0.28780794],
#         [0.2831328 ]],
#
#        [[0.2831328 ],
#         [0.27938111]],
#
#        [[0.27938111],
#         [0.27828274]],
#
#        [[0.27828274],
#         [0.28186517]],
#
#        [[0.28186517],
#         [0.24293778]],
#
#        [[0.24293778],
#         [0.22121752]],
#
#        [[0.22121752],
#         [0.2289973 ]],
#
#        [[0.2289973 ],
#         [0.21676963]],
#
#        [[0.21676963],
#         [0.21579495]],
#
#        [[0.21579495],
#         [0.19165588]],
#
#        [[0.19165588],
#         [0.19834401]],
#
#        [[0.19834401],
#         [0.18639533]],
#
#        [[0.18639533],
#         [0.18854811]],
#
#        [[0.18854811],
#         [0.21115245]],
#
#        [[0.21115245],
#         [0.21226153]],
#
#        [[0.21226153],
#         [0.1987218 ]],
#
#        [[0.1987218 ],
#         [0.20893974]],
#
#        [[0.20893974],
#         [0.20506827]],
#
#        [[0.20506827],
#         [0.19234798]],
#
#        [[0.19234798],
#         [0.1955967 ]],
#
#        [[0.1955967 ],
#         [0.1850943 ]],
#
#        [[0.1850943 ],
#         [0.17303936]],
#
#        [[0.17303936],
#         [0.16780291]],
#
#        [[0.16780291],
#         [0.17071075]],
#
#        [[0.17071075],
#         [0.17786006]],
#
#        [[0.17786006],
#         [0.17208457]],
#
#        [[0.17208457],
#         [0.16804364]],
#
#        [[0.16804364],
#         [0.17127161]],
#
#        [[0.17127161],
#         [0.16230271]],
#
#        [[0.16230271],
#         [0.15861767]],
#
#        [[0.15861767],
#         [0.15832143]],
#
#        [[0.15832143],
#         [0.15915362]],
#
#        [[0.15915362],
#         [0.17432113]],
#
#        [[0.17432113],
#         [0.18209545]],
#
#        [[0.18209545],
#         [0.18467792]],
#
#        [[0.18467792],
#         [0.20478687]],
#
#        [[0.20478687],
#         [0.19247287]],
#
#        [[0.19247287],
#         [0.19856207]],
#
#        [[0.19856207],
#         [0.19777516]],
#
#        [[0.19777516],
#         [0.20189638]],
#
#        [[0.20189638],
#         [0.18827743]],
#
#        [[0.18827743],
#         [0.19044143]],
#
#        [[0.19044143],
#         [0.17996154]],
#
#        [[0.17996154],
#         [0.19388985]],
#
#        [[0.19388985],
#         [0.188532  ]],
#
#        [[0.188532  ],
#         [0.19088943]],
#
#        [[0.19088943],
#         [0.18450968]],
#
#        [[0.18450968],
#         [0.18972828]],
#
#        [[0.18972828],
#         [0.19489872]],
#
#        [[0.19489872],
#         [0.1893774 ]],
#
#        [[0.1893774 ],
#         [0.19046317]],
#
#        [[0.19046317],
#         [0.18981496]],
#
#        [[0.18981496],
#         [0.20179458]],
#
#        [[0.20179458],
#         [0.19913485]],
#
#        [[0.19913485],
#         [0.19942469]],
#
#        [[0.19942469],
#         [0.19965495]],
#
#        [[0.19965495],
#         [0.18120853]],
#
#        [[0.18120853],
#         [0.18164545]],
#
#        [[0.18164545],
#         [0.18029631]],
#
#        [[0.18029631],
#         [0.17468804]],
#
#        [[0.17468804],
#         [0.18261271]],
#
#        [[0.18261271],
#         [0.17871107]],
#
#        [[0.17871107],
#         [0.17997051]],
#
#        [[0.17997051],
#         [0.18118987]],
#
#        [[0.18118987],
#         [0.18011713]],
#
#        [[0.18011713],
#         [0.18377818]],
#
#        [[0.18377818],
#         [0.17717573]],
#
#        [[0.17717573],
#         [0.17588266]],
#
#        [[0.17588266],
#         [0.17736018]],
#
#        [[0.17736018],
#         [0.17635321]],
#
#        [[0.17635321],
#         [0.17716806]],
#
#        [[0.17716806],
#         [0.17711114]],
#
#        [[0.17711114],
#         [0.17725062]],
#
#        [[0.17725062],
#         [0.17629331]],
#
#        [[0.17629331],
#         [0.17041756]],
#
#        [[0.17041756],
#         [0.16926154]],
#
#        [[0.16926154],
#         [0.17123183]],
#
#        [[0.17123183],
#         [0.16976237]],
#
#        [[0.16976237],
#         [0.17132312]],
#
#        [[0.17132312],
#         [0.17303723]],
#
#        [[0.17303723],
#         [0.17008437]],
#
#        [[0.17008437],
#         [0.16983284]],
#
#        [[0.16983284],
#         [0.17020569]],
#
#        [[0.17020569],
#         [0.16748357]],
#
#        [[0.16748357],
#         [0.16674357]],
#
#        [[0.16674357],
#         [0.18057993]],
#
#        [[0.18057993],
#         [0.18080888]],
#
#        [[0.18080888],
#         [0.18179156]],
#
#        [[0.18179156],
#         [0.17963012]],
#
#        [[0.17963012],
#         [0.17989399]],
#
#        [[0.17989399],
#         [0.17878329]],
#
#        [[0.17878329],
#         [0.17799705]],
#
#        [[0.17799705],
#         [0.17820047]],
#
#        [[0.17820047],
#         [0.17866512]],
#
#        [[0.17866512],
#         [0.18094515]],
#
#        [[0.18094515],
#         [0.19346518]],
#
#        [[0.19346518],
#         [0.19508947]],
#
#        [[0.19508947],
#         [0.19781866]],
#
#        [[0.19781866],
#         [0.19545303]],
#
#        [[0.19545303],
#         [0.19811402]],
#
#        [[0.19811402],
#         [0.20520538]],
#
#        [[0.20520538],
#         [0.18801535]],
#
#        [[0.18801535],
#         [0.19175611]],
#
#        [[0.19175611],
#         [0.19028927]],
#
#        [[0.19028927],
#         [0.19011791]],
#
#        [[0.19011791],
#         [0.19031139]],
#
#        [[0.19031139],
#         [0.19055976]],
#
#        [[0.19055976],
#         [0.19080984]],
#
#        [[0.19080984],
#         [0.18991751]],
#
#        [[0.18991751],
#         [0.18548574]],
#
#        [[0.18548574],
#         [0.19246414]],
#
#        [[0.19246414],
#         [0.19285586]],
#
#        [[0.19285586],
#         [0.19324623]],
#
#        [[0.19324623],
#         [0.19271035]],
#
#        [[0.19271035],
#         [0.19592901]],
#
#        [[0.19592901],
#         [0.19532268]],
#
#        [[0.19532268],
#         [0.19292235]],
#
#        [[0.19292235],
#         [0.19312572]],
#
#        [[0.19312572],
#         [0.19299948]],
#
#        [[0.19299948],
#         [0.19391317]],
#
#        [[0.19391317],
#         [0.19580464]],
#
#        [[0.19580464],
#         [0.20035008]],
#
#        [[0.20035008],
#         [0.19913385]],
#
#        [[0.19913385],
#         [0.19951059]],
#
#        [[0.19951059],
#         [0.20151288]],
#
#        [[0.20151288],
#         [0.20235587]],
#
#        [[0.20235587],
#         [0.19934596]],
#
#        [[0.19934596],
#         [0.19906859]],
#
#        [[0.19906859],
#         [0.19968239]],
#
#        [[0.19968239],
#         [0.19897541]],
#
#        [[0.19897541],
#         [0.19591642]],
#
#        [[0.19591642],
#         [0.19705571]],
#
#        [[0.19705571],
#         [0.20233464]],
#
#        [[0.20233464],
#         [0.20140506]],
#
#        [[0.20140506],
#         [0.20291998]],
#
#        [[0.20291998],
#         [0.20334886]],
#
#        [[0.20334886],
#         [0.20328386]],
#
#        [[0.20328386],
#         [0.20601578]],
#
#        [[0.20601578],
#         [0.24337194]],
#
#        [[0.24337194],
#         [0.24819324]],
#
#        [[0.24819324],
#         [0.2455936 ]],
#
#        [[0.2455936 ],
#         [0.25148835]],
#
#        [[0.25148835],
#         [0.25268592]],
#
#        [[0.25268592],
#         [0.25988492]],
#
#        [[0.25988492],
#         [0.26458871]],
#
#        [[0.26458871],
#         [0.26019867]],
#
#        [[0.26019867],
#         [0.26638902]],
#
#        [[0.26638902],
#         [0.25292767]],
#
#        [[0.25292767],
#         [0.25422436]],
#
#        [[0.25422436],
#         [0.25458915]],
#
#        [[0.25458915],
#         [0.25827125]],
#
#        [[0.25827125],
#         [0.25306331]],
#
#        [[0.25306331],
#         [0.26178263]],
#
#        [[0.26178263],
#         [0.26263041]],
#
#        [[0.26263041],
#         [0.26503463]],
#
#        [[0.26503463],
#         [0.26531552]],
#
#        [[0.26531552],
#         [0.26707924]],
#
#        [[0.26707924],
#         [0.26587034]],
#
#        [[0.26587034],
#         [0.2702615 ]],
#
#        [[0.2702615 ],
#         [0.2792161 ]],
#
#        [[0.2792161 ],
#         [0.27365197]],
#
#        [[0.27365197],
#         [0.26048632]],
#
#        [[0.26048632],
#         [0.26404921]],
#
#        [[0.26404921],
#         [0.26347687]],
#
#        [[0.26347687],
#         [0.26434896]],
#
#        [[0.26434896],
#         [0.26239306]],
#
#        [[0.26239306],
#         [0.26774388]],
#
#        [[0.26774388],
#         [0.27043397]],
#
#        [[0.27043397],
#         [0.27574402]],
#
#        [[0.27574402],
#         [0.28935765]],
#
#        [[0.28935765],
#         [0.29261232]],
#
#        [[0.29261232],
#         [0.2907769 ]],
#
#        [[0.2907769 ],
#         [0.28824569]],
#
#        [[0.28824569],
#         [0.29252609]],
#
#        [[0.29252609],
#         [0.30044335]],
#
#        [[0.30044335],
#         [0.31038529]],
#
#        [[0.31038529],
#         [0.32096126]]])

# %%
y_val
# Out:
# array([0.31641043, 0.33222932, 0.33220705, 0.32953202, 0.32602671,
#        0.32544181, 0.32667269, 0.32631865, 0.32656763, 0.32597652,
#        0.32701691, 0.32600497, 0.32592526, 0.32621667, 0.32652777,
#        0.31856888, 0.31865377, 0.31779142, 0.32090591, 0.3214577 ,
#        0.32005081, 0.32082051, 0.32307371, 0.32521404, 0.32879235,
#        0.32483672, 0.32131174, 0.32253332, 0.32263943, 0.32056896,
#        0.31995922, 0.28780794, 0.2831328 , 0.27938111, 0.27828274,
#        0.28186517, 0.24293778, 0.22121752, 0.2289973 , 0.21676963,
#        0.21579495, 0.19165588, 0.19834401, 0.18639533, 0.18854811,
#        0.21115245, 0.21226153, 0.1987218 , 0.20893974, 0.20506827,
#        0.19234798, 0.1955967 , 0.1850943 , 0.17303936, 0.16780291,
#        0.17071075, 0.17786006, 0.17208457, 0.16804364, 0.17127161,
#        0.16230271, 0.15861767, 0.15832143, 0.15915362, 0.17432113,
#        0.18209545, 0.18467792, 0.20478687, 0.19247287, 0.19856207,
#        0.19777516, 0.20189638, 0.18827743, 0.19044143, 0.17996154,
#        0.19388985, 0.188532  , 0.19088943, 0.18450968, 0.18972828,
#        0.19489872, 0.1893774 , 0.19046317, 0.18981496, 0.20179458,
#        0.19913485, 0.19942469, 0.19965495, 0.18120853, 0.18164545,
#        0.18029631, 0.17468804, 0.18261271, 0.17871107, 0.17997051,
#        0.18118987, 0.18011713, 0.18377818, 0.17717573, 0.17588266,
#        0.17736018, 0.17635321, 0.17716806, 0.17711114, 0.17725062,
#        0.17629331, 0.17041756, 0.16926154, 0.17123183, 0.16976237,
#        0.17132312, 0.17303723, 0.17008437, 0.16983284, 0.17020569,
#        0.16748357, 0.16674357, 0.18057993, 0.18080888, 0.18179156,
#        0.17963012, 0.17989399, 0.17878329, 0.17799705, 0.17820047,
#        0.17866512, 0.18094515, 0.19346518, 0.19508947, 0.19781866,
#        0.19545303, 0.19811402, 0.20520538, 0.18801535, 0.19175611,
#        0.19028927, 0.19011791, 0.19031139, 0.19055976, 0.19080984,
#        0.18991751, 0.18548574, 0.19246414, 0.19285586, 0.19324623,
#        0.19271035, 0.19592901, 0.19532268, 0.19292235, 0.19312572,
#        0.19299948, 0.19391317, 0.19580464, 0.20035008, 0.19913385,
#        0.19951059, 0.20151288, 0.20235587, 0.19934596, 0.19906859,
#        0.19968239, 0.19897541, 0.19591642, 0.19705571, 0.20233464,
#        0.20140506, 0.20291998, 0.20334886, 0.20328386, 0.20601578,
#        0.24337194, 0.24819324, 0.2455936 , 0.25148835, 0.25268592,
#        0.25988492, 0.26458871, 0.26019867, 0.26638902, 0.25292767,
#        0.25422436, 0.25458915, 0.25827125, 0.25306331, 0.26178263,
#        0.26263041, 0.26503463, 0.26531552, 0.26707924, 0.26587034,
#        0.2702615 , 0.2792161 , 0.27365197, 0.26048632, 0.26404921,
#        0.26347687, 0.26434896, 0.26239306, 0.26774388, 0.27043397,
#        0.27574402, 0.28935765, 0.29261232, 0.2907769 , 0.28824569,
#        0.29252609, 0.30044335, 0.31038529, 0.32096126, 0.36371242])

# %%
plt.figure(figsize=(8, 4), dpi=80)
plt.hist(df.Close, bins=20, color='k')
plt.title('Close')
plt.show()

# %%
plt.figure(figsize=(8, 4), dpi=80)
plt.hist(bitcoin.High, bins=20, color='r')
plt.title('Adj Close of the bitcoin')
plt.show()

# %% [markdown]
# # Model GRU

# %%
# Hyperparameters
learning_rate = 0.0001
hidden_unit = 64
batch_size=256
epoch = 100

# Architecture Gated Recurrent Unit
regressorGRU = Sequential()

# First GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=True, input_shape=(x_train.shape[1],1), activation = 'tanh'))
regressorGRU.add(Dropout(0.2))
# Second GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=True, activation = 'tanh'))
regressorGRU.add(Dropout(0.2))
# Third GRU layer with dropout
regressorGRU.add(GRU(units=hidden_unit, return_sequences=False, activation = 'tanh'))
regressorGRU.add(Dropout(0.2))

# Output layer
regressorGRU.add(Dense(units=1))

# Compiling the Gated Recurrent Unit
regressorGRU.compile(optimizer=optimizers.Adam(lr=learning_rate),loss='mean_squared_error')

# Fitting ke data training dan data validation
pred = regressorGRU.fit(x_train, y_train, validation_data=(x_val,y_val), batch_size=batch_size, epochs=epoch)
# Out:
# WARNING:tensorflow:From C:\Users\admin\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\admin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\admin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 6/6 [==============================] - 11s 365ms/step - loss: 0.0394 - val_loss: 0.0070
# Epoch 2/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0229 - val_loss: 0.0013
# Epoch 3/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0127 - val_loss: 0.0018
# Epoch 4/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0031 - val_loss: 2.7520e-04
# Epoch 5/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0032 - val_loss: 5.1238e-04
# Epoch 6/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0021 - val_loss: 9.0381e-04
# Epoch 7/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0015 - val_loss: 1.6538e-04
# Epoch 8/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0016 - val_loss: 4.2014e-04
# Epoch 9/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 1.1921e-04
# Epoch 10/100
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 1.2370e-04
# Epoch 11/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 2.1189e-04
# Epoch 12/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0011 - val_loss: 9.8692e-05
# Epoch 13/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 1.7759e-04
# Epoch 14/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 9.7182e-05
# Epoch 15/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0011 - val_loss: 1.1931e-04
# Epoch 16/100
# 6/6 [==============================] - 0s 26ms/step - loss: 9.3657e-04 - val_loss: 1.0305e-04
# Epoch 17/100
# 6/6 [==============================] - 0s 24ms/step - loss: 9.7830e-04 - val_loss: 1.2149e-04
# Epoch 18/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0011 - val_loss: 1.0823e-04
# Epoch 19/100
# 6/6 [==============================] - 0s 24ms/step - loss: 9.9450e-04 - val_loss: 9.4709e-05
# Epoch 20/100
# 6/6 [==============================] - 0s 28ms/step - loss: 8.2091e-04 - val_loss: 1.3393e-04
# Epoch 21/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0010 - val_loss: 9.5043e-05
# Epoch 22/100
# 6/6 [==============================] - 0s 24ms/step - loss: 9.1389e-04 - val_loss: 1.0762e-04
# Epoch 23/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0011 - val_loss: 9.5569e-05
# Epoch 24/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.5242e-04 - val_loss: 1.0055e-04
# Epoch 25/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 1.1241e-04
# Epoch 26/100
# 6/6 [==============================] - 0s 29ms/step - loss: 8.8565e-04 - val_loss: 9.6184e-05
# Epoch 27/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0012 - val_loss: 1.1297e-04
# Epoch 28/100
# 6/6 [==============================] - 0s 29ms/step - loss: 9.8295e-04 - val_loss: 9.3832e-05
# Epoch 29/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 9.5026e-05
# Epoch 30/100
# 6/6 [==============================] - 0s 26ms/step - loss: 9.8266e-04 - val_loss: 9.3467e-05
# Epoch 31/100
# 6/6 [==============================] - 0s 28ms/step - loss: 8.5161e-04 - val_loss: 9.3184e-05
# Epoch 32/100
# 6/6 [==============================] - 0s 23ms/step - loss: 9.1350e-04 - val_loss: 9.6417e-05
# Epoch 33/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.0952e-04 - val_loss: 1.0104e-04
# Epoch 34/100
# 6/6 [==============================] - 0s 25ms/step - loss: 8.9324e-04 - val_loss: 1.0609e-04
# Epoch 35/100
# 6/6 [==============================] - 0s 29ms/step - loss: 8.8090e-04 - val_loss: 9.3324e-05
# Epoch 36/100
# 6/6 [==============================] - 0s 29ms/step - loss: 9.4701e-04 - val_loss: 9.3668e-05
# Epoch 37/100
# 6/6 [==============================] - 0s 36ms/step - loss: 9.5026e-04 - val_loss: 9.6348e-05
# Epoch 38/100
# 6/6 [==============================] - 0s 29ms/step - loss: 9.5623e-04 - val_loss: 1.0555e-04
# Epoch 39/100
# 6/6 [==============================] - 0s 29ms/step - loss: 9.3833e-04 - val_loss: 9.3920e-05
# Epoch 40/100
# 6/6 [==============================] - 0s 30ms/step - loss: 8.5687e-04 - val_loss: 1.2357e-04
# Epoch 41/100
# 6/6 [==============================] - 0s 36ms/step - loss: 9.1848e-04 - val_loss: 9.2746e-05
# Epoch 42/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.1949e-04 - val_loss: 9.3995e-05
# Epoch 43/100
# 6/6 [==============================] - 0s 24ms/step - loss: 9.1060e-04 - val_loss: 9.6623e-05
# Epoch 44/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.8384e-04 - val_loss: 1.0103e-04
# Epoch 45/100
# 6/6 [==============================] - 0s 22ms/step - loss: 7.5819e-04 - val_loss: 9.3133e-05
# Epoch 46/100
# 6/6 [==============================] - 0s 23ms/step - loss: 9.7612e-04 - val_loss: 1.0368e-04
# Epoch 47/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.8548e-04 - val_loss: 9.4144e-05
# Epoch 48/100
# 6/6 [==============================] - 0s 23ms/step - loss: 9.2914e-04 - val_loss: 9.3290e-05
# Epoch 49/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.3617e-04 - val_loss: 9.7282e-05
# Epoch 50/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.6924e-04 - val_loss: 9.9320e-05
# Epoch 51/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.8895e-04 - val_loss: 9.2397e-05
# Epoch 52/100
# 6/6 [==============================] - 0s 23ms/step - loss: 8.2963e-04 - val_loss: 9.3769e-05
# Epoch 53/100
# 6/6 [==============================] - 0s 23ms/step - loss: 8.0655e-04 - val_loss: 9.5168e-05
# Epoch 54/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.8330e-04 - val_loss: 9.6110e-05
# Epoch 55/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.2670e-04 - val_loss: 1.2625e-04
# Epoch 56/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.8403e-04 - val_loss: 1.1557e-04
# Epoch 57/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.8301e-04 - val_loss: 1.0680e-04
# Epoch 58/100
# 6/6 [==============================] - 0s 27ms/step - loss: 7.6696e-04 - val_loss: 1.5197e-04
# Epoch 59/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.9911e-04 - val_loss: 1.1714e-04
# Epoch 60/100
# 6/6 [==============================] - 0s 22ms/step - loss: 7.9429e-04 - val_loss: 1.3241e-04
# Epoch 61/100
# 6/6 [==============================] - 0s 23ms/step - loss: 9.0164e-04 - val_loss: 3.3838e-04
# Epoch 62/100
# 6/6 [==============================] - 0s 24ms/step - loss: 8.0046e-04 - val_loss: 9.4240e-05
# Epoch 63/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.1512e-04 - val_loss: 1.1698e-04
# Epoch 64/100
# 6/6 [==============================] - 0s 29ms/step - loss: 8.3978e-04 - val_loss: 9.2200e-05
# Epoch 65/100
# 6/6 [==============================] - 0s 28ms/step - loss: 8.4973e-04 - val_loss: 1.2789e-04
# Epoch 66/100
# 6/6 [==============================] - 0s 23ms/step - loss: 8.4842e-04 - val_loss: 9.4284e-05
# Epoch 67/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.3735e-04 - val_loss: 1.7081e-04
# Epoch 68/100
# 6/6 [==============================] - 0s 26ms/step - loss: 8.6972e-04 - val_loss: 9.2634e-05
# Epoch 69/100
# 6/6 [==============================] - 0s 29ms/step - loss: 7.8010e-04 - val_loss: 1.6993e-04
# Epoch 70/100
# 6/6 [==============================] - 0s 23ms/step - loss: 8.2861e-04 - val_loss: 1.3589e-04
# Epoch 71/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.0670e-04 - val_loss: 1.3122e-04
# Epoch 72/100
# 6/6 [==============================] - 0s 21ms/step - loss: 7.7848e-04 - val_loss: 9.5784e-05
# Epoch 73/100
# 6/6 [==============================] - 0s 24ms/step - loss: 7.4937e-04 - val_loss: 9.2964e-05
# Epoch 74/100
# 6/6 [==============================] - 0s 32ms/step - loss: 9.2818e-04 - val_loss: 9.8319e-05
# Epoch 75/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.7574e-04 - val_loss: 1.0067e-04
# Epoch 76/100
# 6/6 [==============================] - 0s 23ms/step - loss: 6.9202e-04 - val_loss: 9.3582e-05
# Epoch 77/100
# 6/6 [==============================] - 0s 24ms/step - loss: 6.8535e-04 - val_loss: 1.0115e-04
# Epoch 78/100
# 6/6 [==============================] - 0s 25ms/step - loss: 7.9876e-04 - val_loss: 9.4192e-05
# Epoch 79/100
# 6/6 [==============================] - 0s 24ms/step - loss: 6.6426e-04 - val_loss: 1.6474e-04
# Epoch 80/100
# 6/6 [==============================] - 0s 26ms/step - loss: 8.0432e-04 - val_loss: 9.9099e-05
# Epoch 81/100
# 6/6 [==============================] - 0s 27ms/step - loss: 7.3638e-04 - val_loss: 1.1815e-04
# Epoch 82/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.4379e-04 - val_loss: 1.7673e-04
# Epoch 83/100
# 6/6 [==============================] - 0s 27ms/step - loss: 7.7960e-04 - val_loss: 1.8249e-04
# Epoch 84/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.7175e-04 - val_loss: 9.2886e-05
# Epoch 85/100
# 6/6 [==============================] - 0s 27ms/step - loss: 7.8759e-04 - val_loss: 9.1703e-05
# Epoch 86/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.2827e-04 - val_loss: 9.4529e-05
# Epoch 87/100
# 6/6 [==============================] - 0s 29ms/step - loss: 6.7539e-04 - val_loss: 1.0157e-04
# Epoch 88/100
# 6/6 [==============================] - 0s 25ms/step - loss: 6.3898e-04 - val_loss: 9.4831e-05
# Epoch 89/100
# 6/6 [==============================] - 0s 27ms/step - loss: 7.3370e-04 - val_loss: 1.3155e-04
# Epoch 90/100
# 6/6 [==============================] - 0s 23ms/step - loss: 6.6479e-04 - val_loss: 1.8130e-04
# Epoch 91/100
# 6/6 [==============================] - 0s 28ms/step - loss: 7.3703e-04 - val_loss: 9.8402e-05
# Epoch 92/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.9174e-04 - val_loss: 1.0706e-04
# Epoch 93/100
# 6/6 [==============================] - 0s 26ms/step - loss: 7.3645e-04 - val_loss: 1.1341e-04
# Epoch 94/100
# 6/6 [==============================] - 0s 28ms/step - loss: 6.8962e-04 - val_loss: 9.0834e-05
# Epoch 95/100
# 6/6 [==============================] - 0s 25ms/step - loss: 7.3416e-04 - val_loss: 1.1278e-04
# Epoch 96/100
# 6/6 [==============================] - 0s 28ms/step - loss: 7.3831e-04 - val_loss: 9.1975e-05
# Epoch 97/100
# 6/6 [==============================] - 0s 23ms/step - loss: 7.7680e-04 - val_loss: 1.0689e-04
# Epoch 98/100
# 6/6 [==============================] - 0s 28ms/step - loss: 6.9068e-04 - val_loss: 9.5543e-05
# Epoch 99/100
# 6/6 [==============================] - 0s 22ms/step - loss: 6.2407e-04 - val_loss: 9.4967e-05
# Epoch 100/100
# 6/6 [==============================] - 0s 27ms/step - loss: 5.9368e-04 - val_loss: 1.0839e-04

# %%
# Graph model loss (train loss & val loss)
fig = plt.figure(figsize=(10, 4))
plt.plot(pred.history['loss'], label='train loss')
plt.plot(pred.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()

# %%
# Tabel value of training loss & validation loss
learningrate_parameter = learning_rate
train_loss=pred.history['loss'][-1]
validation_loss=pred.history['val_loss'][-1]
learningrate_parameter=pd.DataFrame(data=[[learningrate_parameter, train_loss, validation_loss]],
                                    columns=['Learning Rate', 'Training Loss', 'Validation Loss'])
learningrate_parameter.set_index('Learning Rate')
# Out:
#                Training Loss  Validation Loss
# Learning Rate
# 0.0001              0.000594         0.000108

# %%
# Implementation model into data test
y_pred_test = regressorGRU.predict(x_test)

# Invert normalization min-max
y_pred_invert_norm = scaler.inverse_transform(y_pred_test)
# Out:
# 14/14 [==============================] - 2s 5ms/step

# %%
# Comparison data test with data prediction
datacompare = pd.DataFrame()
df=np.array(df['Close'][totaldatatrain+totaldataval+lag:])
datapred= y_pred_invert_norm

datacompare['Data Test'] = df
datacompare['Prediction Results'] = datapred
datacompare
# Out:
#        Data Test  Prediction Results
# 0    7994.416016         7336.271484
# 1    8205.167969         7905.043457
# 2    7884.909180         8090.745605
# 3    7343.895508         8095.448242
# 4    7271.208008         7701.903320
# ..           ...                 ...
# 418  9073.942383         9083.680664
# 419  9375.474609         9088.447266
# 420  9252.277344         9166.434570
# 421  9428.333008         9297.893555
# 422  9357.105469         9291.038086
#
# [423 rows x 2 columns]

# %%
# Calculatre value of Root Mean Square Error
from sklearn.metrics import r2_score
def rmse(df, datapred):
    return np.round(np.sqrt(np.mean((datapred - df) ** 2)), 4)
print('Root Mean Square Error :',rmse(df, datapred))

def mape(datatest, datapred): 
    return np.round(np.mean(np.abs((df - datapred) / df) * 100), 4)
    
print('Mean Absolute Percentage Error : ', mape(df, datapred), '%')
print(r2_score(df, datapred))
# Out:
# Root Mean Square Error : 1947.1232
# Mean Absolute Percentage Error :  18.2809 %
# 0.9165655036007553

# %%
# Create graph data test and prediction result
plt.figure(num=None, figsize=(10, 4), dpi=80,facecolor='w', edgecolor='k')
plt.title('Graph Comparison Data Actual and Data Prediction')
plt.plot(datacompare['Data Test'], color='red',label='Data Test')
plt.plot(datacompare['Prediction Results'], color='blue',label='Prediction Results')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import pickle
filename='bitcoin.sav'
pickle.dump(regressorGRU ,open('bitcoin.sav','wb'))
loaded_model=pickle.load(open('bitcoin.sav','rb'))
